# %% [markdown]
# <a href="https://colab.research.google.com/github/deepadharshinip18-wq/codealpha_tasks/blob/main/Task3_DataVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Qqimport matplotlib.pyplot as plt

df['species'].value_counts().plot(kind='bar')
plt.title("Species Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2011/4143235333.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 df['species'].value_counts().plot(kind='bar')
#       4 plt.title("Species Count")
#       5 plt.show()
#
# NameError: name 'df' is not defined
